# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from io import StringIO
import pandas as pd
import requests

r = requests.get('https://www.caiso.com/outlook/SP/History/20190301/netdemand.csv')
df = pd.read_csv(StringIO(r.text))
df = df.T
label = 'Net Demand 03/01/2019'
df.rename(columns={label: ' '}, inplace=True)
df.rename(index={'Net demand': label}, inplace=True)
df = df.drop(['Hour ahead forecast', 'Current demand'])
df.head()
# Out:
#                            0        1        2        3        4        5    \
# Time                     00:00    00:05    00:10    00:15    00:20    00:25
# Net Demand 03/01/2019  18085.0  17930.0  17982.0  17854.0  17777.0  17647.0
#
#                            6        7        8        9    ...      279  \
# Time                     00:30    00:35    00:40    00:45  ...    23:15
# Net Demand 03/01/2019  17574.0  17505.0  17486.0  17372.0  ...  20941.0
#
#                            280      281      282      283      284      285  \
# Time                     23:20    23:25    23:30    23:35    23:40    23:45
# Net Demand 03/01/2019  20797.0  20673.0  20566.0  20398.0  20272.0  20165.0
#
#                            286      287    288
# Time                     23:50    23:55  00:00
# Net Demand 03/01/2019  20049.0  19972.0    NaN
#
# [2 rows x 289 columns]

# %%
from io import StringIO
import pandas as pd
import requests
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

r = requests.get('https://www.caiso.com/outlook/SP/History/20210401/netdemand.csv')
df = pd.read_csv(StringIO(r.text))
df = df.T
label = 'Net Demand 04/01/2021'
df.rename(columns={label: ' '}, inplace=True)
df.rename(index={'Net demand': label}, inplace=True)
df = df.drop(['Hour ahead forecast', 'Current demand'])

dfs = [df]

for i in tqdm(range(2, 31)):
    if i < 10:
        r = requests.get('https://www.caiso.com/outlook/SP/History/2021040' + str(i) + '/netdemand.csv')
        df = pd.read_csv(StringIO(r.text))
        df = df.T
        label = 'Net Demand 04/0' + str(i) + '/2021'
    else:
        r = requests.get('https://www.caiso.com/outlook/SP/History/202104' + str(i) + '/netdemand.csv')
        df = pd.read_csv(StringIO(r.text))
        df = df.T
        label = 'Net Demand 04/' + str(i) + '/2021'
    df.rename(columns={label: ' '}, inplace=True)
    df.rename(index={'Net demand': label}, inplace=True)
    df = df.drop(['Time', 'Hour ahead forecast', 'Current demand'])
    dfs.append(df)

df_load = pd.concat(dfs)
df_load.to_csv('CAISO-netdemand-2021-04.csv')
df_load.head()
# Out:
# 100%|██████████| 29/29 [00:10<00:00,  2.83it/s]
#                            0        1        2        3        4        5    \
# Time                     00:00    00:05    00:10    00:15    00:20    00:25
# Net Demand 04/01/2021  21128.0  21024.0  20921.0  20897.0  20811.0  20769.0
# Net Demand 04/02/2021  20154.0  20044.0  19956.0  19821.0  19627.0  19496.0
# Net Demand 04/03/2021  18497.0  18392.0  18308.0  18237.0  18218.0  18114.0
# Net Demand 04/04/2021  17137.0  17004.0  16960.0  16831.0  16675.0  16557.0
#
#                            6        7        8        9    ...      279  \
# Time                     00:30    00:35    00:40    00:45  ...    23:15
# Net Demand 04/01/2021  20703.0  20571.0  20441.0  20368.0  ...  21253.0
# Net Demand 04/02/2021  19470.0  19424.0  19439.0  19382.0  ...  18886.0
# Net Demand 04/03/2021  18016.0  17935.0  17903.0  17791.0  ...  18024.0
# Net Demand 04/04/2021  16459.0  16398.0  16340.0  16223.0  ...  16374.0
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

dfs = []

for i in range(1, 32):
    if i < 10:
        df = pd.read_csv('data/CAISO-netdemand-2019030%d.csv' % i, on_bad_lines='skip')
        label = 'Net Demand 05/0' + str(i) + '/2021'
    else:
        df = pd.read_csv('data/CAISO-netdemand-201903%d.csv' % i, on_bad_lines='skip')
        label = 'Net Demand 05/' + str(i) + '/2021'
    df.rename(columns={label: ' '}, inplace=True)
    df.iloc[1, 0] = label
    df.drop([0], inplace=True)
    dfs.append(df)

df_load = pd.concat(dfs)
df_load.to_csv('CAISO-netdemand-2021-05.csv')
df_load.head()
# Out:
#                             00:00    00:05    00:10    00:15    00:20  \
# 1  Net Demand 05/01/2021  23656.0  23599.0  23552.0  23327.0  23216.0
# 1  Net Demand 05/02/2021  21605.0  21606.0  21553.0  21438.0  21368.0
# 1  Net Demand 05/03/2021  20875.0  20944.0  20890.0  20792.0  20711.0
# 1  Net Demand 05/04/2021  23020.0  22899.0  22901.0  22784.0  22681.0
# 1  Net Demand 05/05/2021  23708.0  23599.0  23599.0  23522.0  23392.0
#
#      00:25    00:30    00:35    00:40  ...  9:15  9:20  9:25  9:30  9:35  \
# 1  23111.0  22980.0  22865.0  22731.0  ...   NaN   NaN   NaN   NaN   NaN
# 1  21279.0  21180.0  21110.0  21066.0  ...   NaN   NaN   NaN   NaN   NaN
# 1  20629.0  20563.0  20529.0  20446.0  ...   NaN   NaN   NaN   NaN   NaN
# 1  22564.0  22497.0  22391.0  22279.0  ...   NaN   NaN   NaN   NaN   NaN
# 1  23296.0  23178.0  23094.0  22985.0  ...   NaN   NaN   NaN   NaN   NaN
#
#    9:40  9:45  9:50  9:55  0:00.1
# 1   NaN   NaN   NaN   NaN     NaN
# 1   NaN   NaN   NaN   NaN     NaN
# ...

# %%
import pandas as pd

df = pd.read_csv('data/CAISO-netdemand-2020-05.csv.gz', compression='gzip', index_col=0)
df.head()
# Out:
#               00:00    00:05    00:10    00:15    00:20    00:25    00:30  \
# 2020-05-01  17715.0  17681.0  17698.0  17546.0  17444.0  17325.0  17210.0
# 2020-05-02  16851.0  16734.0  16759.0  16634.0  16567.0  16433.0  16380.0
# 2020-05-03  16569.0  16560.0  16693.0  16702.0  16701.0  16663.0  16681.0
# 2020-05-04  16421.0  16416.0  16377.0  16284.0  16227.0  16137.0  16078.0
# 2020-05-05  20365.0  20327.0  20304.0  20204.0  20129.0  20084.0  20029.0
#
#               00:35    00:40    00:45  ...    23:15    23:20    23:25  \
# 2020-05-01  17068.0  16960.0  16896.0  ...  18150.0  18032.0  17866.0
# 2020-05-02  16269.0  16200.0  16090.0  ...  17982.0  17751.0  17588.0
# 2020-05-03  16629.0  16596.0  16553.0  ...  17103.0  16946.0  16871.0
# 2020-05-04  15966.0  15873.0  15767.0  ...  21179.0  21085.0  20956.0
# 2020-05-05  19893.0  19752.0  19662.0  ...  19607.0  19438.0  19288.0
#
#               23:30    23:35    23:40    23:45    23:50    23:55  00:00.1
# ...

# %%
import pandas as pd

df = pd.read_csv('data/CAISO-demand-forecast-2020-05.csv.gz', compression='gzip', index_col=0)
df.head()
# Out:
#             00:00  00:05  00:10  00:15  00:20  00:25  00:30  00:35  00:40  \
# 2020-05-01  22426  22087  22087  22087  21845  21845  21845  21505  21505
# 2020-05-02  22131  21845  21845  21845  21560  21560  21560  21155  21155
# 2020-05-03  21294  20984  20984  20984  20753  20753  20753  20476  20476
# 2020-05-04  20567  20321  20321  20321  20324  20324  20324  20069  20069
# 2020-05-05  22252  22096  22096  22096  21754  21754  21754  21376  21376
#
#             00:45  ...  23:15  23:20  23:25  23:30  23:35  23:40  23:45  \
# 2020-05-01  21505  ...  23266  22965  22965  22965  22552  22552  22552
# 2020-05-02  21155  ...  22365  21956  21956  21956  21596  21596  21596
# 2020-05-03  20476  ...  21526  21225  21225  21225  20871  20871  20871
# 2020-05-04  20069  ...  23446  23142  23142  23142  22725  22725  22725
# 2020-05-05  21376  ...  24411  24007  24007  24007  23526  23526  23526
#
#             23:50  23:55  00:00.1
# 2020-05-01  22131  22131    22131
# ...
