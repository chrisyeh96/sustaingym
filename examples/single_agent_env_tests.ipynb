# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
"""
Testing environment with stable_baselines3 library
"""
import sys
sys.path.append('../')

from stable_baselines3.common.env_checker import check_env
from sustaingym.envs.battery.MO_single_agent_battery_storage_env import BatteryStorageInGridEnv

env = BatteryStorageInGridEnv()

check_env(env)
# Out:
# /home/ubuntu/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(

# %%
"""
Testing RL agent which randomly chooses actions
"""
import sys
sys.path.append('../')
from typing import List
import numpy as np
import os
import pandas as pd
import gym

from tqdm import tqdm
import matplotlib.pyplot as plt

env = BatteryStorageInGridEnv(date='2019-05')

episodes = 10

rewards_lst_1 = []
off_line_rewards_lst_1 = []

for i in tqdm(range(episodes)):
    ob = env.reset(seed=i)
    done = False
    rewards = np.zeros(env.MAX_STEPS_PER_EPISODE)

    while not done:
        # random action as policy
        action = env.action_space.sample()
        # print("step: ", env.count)
        # print("charging costs: ", env.bats_charge_costs)
        # print("discharging costs: ", env.bats_discharge_costs)
        # print("env load: ", env.load_demand)
        state, reward, done, info = env.step(action)
        rewards[env.count - 1] = reward
    # print("episode {} mean reward: {}".format(i, np.mean(rewards)))
    rewards_lst_1.append(np.sum(rewards))
    ob = env.reset(seed=i)
    off_line_rewards_lst_1.append(env._calculate_off_optimal_total_episode_reward())

# plot episode # versus total episode reward
plt.subplot(1, 2, 1)
plt.bar(list(range(episodes)), rewards_lst_1, width=0.5)
plt.title("Random Actions")

# naming the y axis 
plt.ylabel('total reward')

# plot episode # versus total offline episode reward
plt.subplot(1, 2, 2)
plt.bar(list(range(episodes)), off_line_rewards_lst_1, width=0.5)
plt.title("Offline Optimal")

# naming the x axis 
plt.xlabel('episode #')

plt.show()
# Out:
# 100%|██████████| 10/10 [00:14<00:00,  1.48s/it]

# %%
# from stable_baselines3 import PPO
# from stable_baselines3.common.callbacks import BaseCallback, EvalCallback, StopTrainingOnNoModelImprovement
# from stable_baselines3.common.monitor import Monitor
# from stable_baselines3.common.results_plotter import load_results, ts2xy

# class PlottingCallback(BaseCallback):
#     """
#     Callback for plotting the performance in realtime.

#     :param verbose: (int)
#     """
#     def __init__(self, verbose=1):
#         super(PlottingCallback, self).__init__(verbose)
#         self._plot = None

#     def _on_step(self) -> bool:
#         # get the monitor's data
#         x, y = ts2xy(load_results(log_dir), 'timesteps')
#         if self._plot is None: # make the plot
#             plt.ion()
#             fig = plt.figure(figsize=(6,3))
#             ax = fig.add_subplot(111)
#             line, = ax.plot(x, y)
#             self._plot = (line, ax, fig)
#             plt.show()
#         else: # update and rescale the plot
#             self._plot[0].set_data(x, y)
#             self._plot[-2].relim()
#             self._plot[-2].set_xlim([self.locals["total_timesteps"] * -0.02, 
#                                     self.locals["total_timesteps"] * 1.02])
#             self._plot[-2].autoscale_view(True,True,True)
#             self._plot[-1].canvas.draw()

# # Create log dir
# log_dir = "/tmp/gym/"
# os.makedirs(log_dir, exist_ok=True)

# env = BatteryStorageInGridEnv(date='2019-05')

# stop_train_callback = StopTrainingOnNoModelImprovement(max_no_improvement_evals=3, min_evals=5, verbose=1)
# eval_callback = EvalCallback(env, eval_freq=1000, callback_after_eval=stop_train_callback, verbose=1)

# model = PPO("MultiInputPolicy", env, verbose=1)
# model.learn(int(1e10), callback=[eval_callback, PlottingCallback()])
# model.save("ppo_single_agent_battery_env")

# del model # remove to demonstrate saving and loading

# model = PPO.load("ppo_single_agent_battery_env")

# episodes = 10

# rewards_lst_4 = []
# off_line_rewards_lst_4 = []

# for i in tqdm(range(episodes)):
#     obs = env.reset(seed=i)
#     done = False
#     start = True
#     rewards = np.zeros(env.MAX_STEPS_PER_EPISODE)
#     avg = np.zeros(1)
#     while not done:
#         action, _states = model.predict(obs)
#         if action.shape[0] == 1:
#             action = action.reshape((2,))
#         obs, reward, done, info = env.step(action)
#         rewards[env.count - 1] = reward
#     rewards_lst_4.append(np.sum(rewards))
#     ob = env.reset(seed=i)
#     off_line_rewards_lst_4.append(env._calculate_off_optimal_total_episode_reward())

# # plot episode # versus total episode reward
# plt.subplot(1, 2, 1)
# plt.bar(list(range(episodes)), rewards_lst_4, width=0.5)
# plt.title("Random Actions")

# # naming the y axis 
# plt.ylabel('total reward')

# # plot episode # versus total offline episode reward
# plt.subplot(1, 2, 2)
# plt.bar(list(range(episodes)), off_line_rewards_lst_4, width=0.5)
# plt.title("Offline Optimal")

# # naming the x axis 
# plt.xlabel('episode #')

# plt.show()
# Out:
# 100%|██████████| 10/10 [00:17<00:00,  1.70s/it]

# %%
# from stable_baselines3.ddpg.policies import MultiInputPolicy
# from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
# from stable_baselines3 import DDPG
# import numpy as np

# env = BatteryStorageInGridEnv(date='2019-05')

# stop_train_callback = StopTrainingOnNoModelImprovement(max_no_improvement_evals=3, min_evals=5, verbose=1)
# eval_callback = EvalCallback(env, eval_freq=1000, callback_after_eval=stop_train_callback, verbose=1)

# # the noise objects for DDPG
# n_actions = env.action_space.shape[-1]
# action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# # model = DDPG(MultiInputPolicy, env, action_noise=action_noise, verbose=1)
# model = DDPG("MultiInputPolicy", env, action_noise=action_noise, verbose=1)
# model.learn(int(1e10), callback=eval_callback)
# model.save("ddpg_single_agent_battery_env")

# # del model # remove to demonstrate saving and loading

# model = DDPG.load("ddpg_single_agent_battery_env")

# episodes = 10

# rewards_lst_2 = []
# off_line_rewards_lst_2 = []

# for i in tqdm(range(episodes)):
#     obs = env.reset(seed=i)
#     done = False
#     start = True
#     rewards = np.zeros(env.MAX_STEPS_PER_EPISODE)
#     avg = np.zeros(1)
#     while not done:
#         action, _states = model.predict(obs)
#         if action.shape[0] == 1:
#             action = action.reshape((2,))
#         obs, reward, done, info = env.step(action)
#         rewards[env.count - 1] = reward
#     rewards_lst_2.append(np.sum(rewards))
#     ob = env.reset(seed=i)
#     off_line_rewards_lst_2.append(env._calculate_off_optimal_total_episode_reward())

# # plot episode # versus total episode reward
# plt.subplot(1, 2, 1)
# plt.bar(list(range(episodes)), rewards_lst_2, width=0.5)
# plt.title("Random Actions")

# # naming the y axis 
# plt.ylabel('total reward')

# # plot episode # versus total offline episode reward
# plt.subplot(1, 2, 2)
# plt.bar(list(range(episodes)), off_line_rewards_lst_2, width=0.5)
# plt.title("Offline Optimal")

# # naming the x axis 
# plt.xlabel('episode #')

# plt.show()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb Cell 5 in <cell line: 17>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bec2-3-142-99-116.us-east-2.compute.amazonaws.com/home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb#ch0000004vscode-remote?line=14'>15</a> # model = DDPG(MultiInputPolicy, env, action_noise=action_noise, verbose=1)
#      <a href='vscode-notebook-cell://ssh-remote%2Bec2-3-142-99-116.us-east-2.compute.amazonaws.com/home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb#ch0000004vscode-remote?line=15'>16</a> model = DDPG("MultiInputPolicy", env, action_noise=action_noise, verbose=1)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bec2-3-142-99-116.us-east-2.compute.amazonaws.com/home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb#ch0000004vscode-remote?line=16'>17</a> model.learn(int(1e10), callback=eval_callback)
#      <a href='vscode-notebook-cell://ssh-remote%2Bec2-3-142-99-116.us-east-2.compute.amazonaws.com/home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb#ch0000004vscode-remote?line=17'>18</a> model.save("ddpg_single_agent_battery_env")
#      <a href='vscode-notebook-cell://ssh-remote%2Bec2-3-142-99-116.us-east-2.compute.amazonaws.com/home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb#ch0000004vscode-remote?line=19'>20</a> # del model # remove to demonstrate saving and loading
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/ddpg/ddpg.py:130, in DDPG.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     117 def learn(
#     118     self,
#     119     total_timesteps: int,
#    (...)
#     127     reset_num_timesteps: bool = True,
#     128 ) -> OffPolicyAlgorithm:
# --> 130     return super().learn(
#     131         total_timesteps=total_timesteps,
#     132         callback=callback,
#     133         log_interval=log_interval,
#     134         eval_env=eval_env,
#     135         eval_freq=eval_freq,
#     136         n_eval_episodes=n_eval_episodes,
#     137         tb_log_name=tb_log_name,
#     138         eval_log_path=eval_log_path,
#     139         reset_num_timesteps=reset_num_timesteps,
#     140     )
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/td3/td3.py:211, in TD3.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     198 def learn(
#     199     self,
#     200     total_timesteps: int,
#    (...)
#     208     reset_num_timesteps: bool = True,
#     209 ) -> OffPolicyAlgorithm:
# --> 211     return super().learn(
#     212         total_timesteps=total_timesteps,
#     213         callback=callback,
#     214         log_interval=log_interval,
#     215         eval_env=eval_env,
#     216         eval_freq=eval_freq,
#     217         n_eval_episodes=n_eval_episodes,
#     218         tb_log_name=tb_log_name,
#     219         eval_log_path=eval_log_path,
#     220         reset_num_timesteps=reset_num_timesteps,
#     221     )
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:346, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     343 callback.on_training_start(locals(), globals())
#     345 while self.num_timesteps < total_timesteps:
# --> 346     rollout = self.collect_rollouts(
#     347         self.env,
#     348         train_freq=self.train_freq,
#     349         action_noise=self.action_noise,
#     350         callback=callback,
#     351         learning_starts=self.learning_starts,
#     352         replay_buffer=self.replay_buffer,
#     353         log_interval=log_interval,
#     354     )
#     356     if rollout.continue_training is False:
#     357         break
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:579, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     576 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     578 # Rescale and perform action
# --> 579 new_obs, rewards, dones, infos = env.step(actions)
#     581 self.num_timesteps += env.num_envs
#     582 num_collected_steps += 1
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:90, in Monitor.step(self, action)
#      88 if self.needs_reset:
#      89     raise RuntimeError("Tried to step environment that needs reset")
# ---> 90 observation, reward, done, info = self.env.step(action)
#      91 self.rewards.append(reward)
#      92 if done:
#
# File ~/sustaingym/sustaingym/tests/../envs/MO_single_agent_battery_storage_env.py:462, in BatteryStorageInGridEnv.step(self, action)
#     460 assert self.init
#     461 assert self.reward_type == 0
# --> 462 assert self.action_space.contains(action)
#     464 self.count += 1
#     466 # ensure selling cost (a) for charge is at least as large as buying cost (b)
#
# AssertionError:

# %%
# from stable_baselines3 import A2C
# from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnNoModelImprovement

# env = BatteryStorageInGridEnv(date='2019-05')

# stop_train_callback = StopTrainingOnNoModelImprovement(max_no_improvement_evals=3, min_evals=5, verbose=1)
# eval_callback = EvalCallback(env, eval_freq=1000, callback_after_eval=stop_train_callback, verbose=1)

# model = A2C("MultiInputPolicy", env, verbose=1)
# model.learn(int(1e10), callback=eval_callback)
# model.save("a2c_single_agent_battery_env")

# del model # remove to demonstrate saving and loading

# model = PPO.load("a2c_single_agent_battery_env")

# episodes = 10

# rewards_lst_3 = []
# off_line_rewards_lst_3 = []

# for i in tqdm(range(episodes)):
#     obs = env.reset(seed=i)
#     done = False
#     start = True
#     rewards = np.zeros(env.MAX_STEPS_PER_EPISODE)
#     avg = np.zeros(1)
#     while not done:
#         action, _states = model.predict(obs)
#         if action.shape[0] == 1:
#             action = action.reshape((2,))
#         obs, reward, done, info = env.step(action)
#         rewards[env.count - 1] = reward
#     rewards_lst_3.append(np.sum(rewards))
#     ob = env.reset(seed=i)
#     off_line_rewards_lst_3.append(env._calculate_off_optimal_total_episode_reward())

# # plot episode # versus total episode reward
# plt.subplot(1, 2, 1)
# plt.bar(list(range(episodes)), rewards_lst_3, width=0.5)
# plt.title("Random Actions")

# # naming the y axis 
# plt.ylabel('total reward')

# # plot episode # versus total offline episode reward
# plt.subplot(1, 2, 2)
# plt.bar(list(range(episodes)), off_line_rewards_lst_3, width=0.5)
# plt.title("Offline Optimal")

# # naming the x axis 
# plt.xlabel('episode #')

# plt.show()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 287      |
# |    ep_rew_mean        | 2.49e+03 |
# | time/                 |          |
# |    fps                | 209      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | -24.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0143  |
# |    std                | 1        |
# |    value_loss         | 3.07e-05 |
# ------------------------------------
# /home/ubuntu/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=1000, episode_reward=2409.92 +/- 74.85
# Episode length: 287.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 287      |
# |    mean_reward        | 2.41e+03 |
# | time/                 |          |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -2.83    |
# |    explained_variance | -1.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0393   |
# |    std                | 0.997    |
# |    value_loss         | 0.000208 |
# ------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 287      |
# |    ep_rew_mean     | 2.5e+03  |
# | time/              |          |
# |    fps             | 102      |
# |    iterations      | 200      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 322      |
# |    ep_rew_mean        | 3.13e+03 |
# | time/                 |          |
# |    fps                | 123      |
# |    iterations         | 300      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -2.83    |
# |    explained_variance | -5.55    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.014    |
# |    std                | 0.998    |
# |    value_loss         | 6.81e-05 |
# ------------------------------------
# Eval num_timesteps=2000, episode_reward=2575.21 +/- 170.36
# Episode length: 287.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 287      |
# |    mean_reward        | 2.58e+03 |
# | time/                 |          |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -2.83    |
# |    explained_variance | 0.105    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.00405 |
# |    std                | 0.998    |
# |    value_loss         | 1.11e-05 |
# ------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 2.88e+03 |
# | time/              |          |
# |    fps             | 102      |
# |    iterations      | 400      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 2000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 327      |
# |    ep_rew_mean        | 3.15e+03 |
# | time/                 |          |
# |    fps                | 114      |
# |    iterations         | 500      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -2.83    |
# |    explained_variance | -0.133   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0408   |
# |    std                | 0.995    |
# |    value_loss         | 0.0003   |
# ------------------------------------
# Eval num_timesteps=3000, episode_reward=2389.82 +/- 72.68
# Episode length: 287.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 287      |
# |    mean_reward        | 2.39e+03 |
# | time/                 |          |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -2.82    |
# |    explained_variance | -9.92    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.00152  |
# |    std                | 0.99     |
# |    value_loss         | 2.03e-05 |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | 2.97e+03 |
# | time/              |          |
# |    fps             | 102      |
# |    iterations      | 600      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 3000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 329      |
# |    ep_rew_mean        | 3.16e+03 |
# | time/                 |          |
# |    fps                | 110      |
# |    iterations         | 700      |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -2.82    |
# |    explained_variance | -10.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.00836 |
# |    std                | 0.993    |
# |    value_loss         | 4.37e-05 |
# ------------------------------------
# Eval num_timesteps=4000, episode_reward=2420.96 +/- 121.50
# Episode length: 287.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 287      |
# |    mean_reward        | 2.42e+03 |
# | time/                 |          |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -2.81    |
# |    explained_variance | -2.85    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0161  |
# |    std                | 0.988    |
# |    value_loss         | 5.22e-05 |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 322      |
# |    ep_rew_mean     | 3.06e+03 |
# | time/              |          |
# |    fps             | 102      |
# |    iterations      | 800      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 4000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 330      |
# |    ep_rew_mean        | 3.18e+03 |
# | time/                 |          |
# |    fps                | 108      |
# |    iterations         | 900      |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -2.83    |
# |    explained_variance | -4.68    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0241   |
# |    std                | 0.995    |
# |    value_loss         | 0.000149 |
# ------------------------------------
# Eval num_timesteps=5000, episode_reward=2647.75 +/- 131.91
# Episode length: 287.00 +/- 0.00
# -------------------------------------
# | eval/                 |           |
# |    mean_ep_length     | 287       |
# |    mean_reward        | 2.65e+03  |
# | time/                 |           |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.83     |
# |    explained_variance | -1.65e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -0.00385  |
# |    std                | 0.996     |
# |    value_loss         | 2.84e-06  |
# -------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 324      |
# |    ep_rew_mean     | 3.11e+03 |
# | time/              |          |
# |    fps             | 102      |
# |    iterations      | 1000     |
# |    time_elapsed    | 48       |
# |    total_timesteps | 5000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 330      |
# |    ep_rew_mean        | 3.25e+03 |
# | time/                 |          |
# |    fps                | 107      |
# |    iterations         | 1100     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | -60.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0194  |
# |    std                | 1        |
# |    value_loss         | 7.69e-05 |
# ------------------------------------
# Eval num_timesteps=6000, episode_reward=2486.03 +/- 110.32
# Episode length: 287.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 287      |
# |    mean_reward        | 2.49e+03 |
# | time/                 |          |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | -59.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.00691 |
# |    std                | 1        |
# |    value_loss         | 0.00012  |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 326      |
# |    ep_rew_mean     | 3.17e+03 |
# | time/              |          |
# |    fps             | 102      |
# |    iterations      | 1200     |
# |    time_elapsed    | 58       |
# |    total_timesteps | 6000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 331      |
# |    ep_rew_mean        | 3.27e+03 |
# | time/                 |          |
# |    fps                | 106      |
# |    iterations         | 1300     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -2.86    |
# |    explained_variance | -0.646   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0219  |
# |    std                | 1.01     |
# |    value_loss         | 4.92e-05 |
# ------------------------------------
# Eval num_timesteps=7000, episode_reward=2426.43 +/- 60.56
# Episode length: 287.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 287      |
# |    mean_reward        | 2.43e+03 |
# | time/                 |          |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -2.83    |
# |    explained_variance | -0.0437  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.0192   |
# |    std                | 0.998    |
# |    value_loss         | 3.9e-05  |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 327      |
# |    ep_rew_mean     | 3.19e+03 |
# | time/              |          |
# |    fps             | 102      |
# |    iterations      | 1400     |
# |    time_elapsed    | 68       |
# |    total_timesteps | 7000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 331      |
# |    ep_rew_mean        | 3.28e+03 |
# | time/                 |          |
# |    fps                | 106      |
# |    iterations         | 1500     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | 0.0276   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.00426 |
# |    std                | 0.999    |
# |    value_loss         | 3.72e-06 |
# ------------------------------------
# Eval num_timesteps=8000, episode_reward=2424.62 +/- 146.32
# Episode length: 287.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 287      |
# |    mean_reward        | 2.42e+03 |
# | time/                 |          |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | 0.363    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.013   |
# |    std                | 1        |
# |    value_loss         | 3.62e-05 |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 328      |
# |    ep_rew_mean     | 3.22e+03 |
# | time/              |          |
# |    fps             | 102      |
# |    iterations      | 1600     |
# |    time_elapsed    | 77       |
# |    total_timesteps | 8000     |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 331      |
# |    ep_rew_mean        | 3.29e+03 |
# | time/                 |          |
# |    fps                | 105      |
# |    iterations         | 1700     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | -3.84    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.0104   |
# |    std                | 1.01     |
# |    value_loss         | 1.28e-05 |
# ------------------------------------
# Eval num_timesteps=9000, episode_reward=2547.32 +/- 138.80
# Episode length: 287.00 +/- 0.00
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 287      |
# |    mean_reward        | 2.55e+03 |
# | time/                 |          |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -2.83    |
# |    explained_variance | -0.275   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0194   |
# |    std                | 0.998    |
# |    value_loss         | 8.57e-05 |
# ------------------------------------
# Stopping training because there was no new best model in the last 4 evaluations
# 100%|██████████| 10/10 [00:17<00:00,  1.78s/it]

# %%
# # Get rewards for Testing on May 2021

# model_ppo = PPO.load("ppo_single_agent_battery_env")
# model_a2c = PPO.load("a2c_single_agent_battery_env")

# episodes = 10

# rewards_lst_ppo_21_5 = []
# rewards_lst_a2c_21_5 = []
# off_line_rewards_lst_21_5 = []

# env1 = BatteryStorageInGridEnv(date='2021-05')
# env2 = BatteryStorageInGridEnv(date='2021-05')

# for i in tqdm(range(episodes)):
#     obs = env1.reset(seed=i)
#     done = False
#     rewards = np.zeros(env1.MAX_STEPS_PER_EPISODE)
#     while not done:
#         action, _states = model_ppo.predict(obs)
#         if action.shape[0] == 1:
#             action = action.reshape((2,))
#         obs, reward, done, info = env1.step(action)
#         rewards[env1.count - 1] = reward
    
#     obs2 = env2.reset(seed=i)
#     done2 = False
#     rewards2 = np.zeros(env2.MAX_STEPS_PER_EPISODE)
#     while not done2:
#         action, _states = model_a2c.predict(obs2)
#         if action.shape[0] == 1:
#             action = action.reshape((2,))
#         obs2, reward, done2, info = env2.step(action)
#         rewards2[env2.count - 1] = reward
#     rewards_lst_ppo_21_5.append(np.sum(rewards))
#     rewards_lst_a2c_21_5.append(np.sum(rewards2))
#     ob = env1.reset(seed=i)
#     off_line_rewards_lst_21_5.append(env1._calculate_off_optimal_total_episode_reward())

# print("2021/5 PPO: ", rewards_lst_ppo_21_5)
# print("2021/5 A2C: ", rewards_lst_a2c_21_5)
# print("2021/5 Offline Optimal: ", off_line_rewards_lst_21_5)
# Out:
#  30%|███       | 3/10 [00:08<00:19,  2.72s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb Cell 7 in <cell line: 15>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bec2-3-142-99-116.us-east-2.compute.amazonaws.com/home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb#ch0000006vscode-remote?line=17'>18</a> rewards = np.zeros(env1.MAX_STEPS_PER_EPISODE)
#      <a href='vscode-notebook-cell://ssh-remote%2Bec2-3-142-99-116.us-east-2.compute.amazonaws.com/home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb#ch0000006vscode-remote?line=18'>19</a> while not done:
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bec2-3-142-99-116.us-east-2.compute.amazonaws.com/home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb#ch0000006vscode-remote?line=19'>20</a>     action, _states = model_ppo.predict(obs)
#      <a href='vscode-notebook-cell://ssh-remote%2Bec2-3-142-99-116.us-east-2.compute.amazonaws.com/home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb#ch0000006vscode-remote?line=20'>21</a>     if action.shape[0] == 1:
#      <a href='vscode-notebook-cell://ssh-remote%2Bec2-3-142-99-116.us-east-2.compute.amazonaws.com/home/ubuntu/sustaingym/sustaingym/tests/single_agent_env_tests.ipynb#ch0000006vscode-remote?line=21'>22</a>         action = action.reshape((2,))
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/base_class.py:579, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     559 def predict(
#     560     self,
#     561     observation: np.ndarray,
#    (...)
#     564     deterministic: bool = False,
#     565 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     566     """
#     567     Get the policy action from an observation (and optional hidden state).
#     568     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     577         (used in recurrent policies)
#     578     """
# --> 579     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/policies.py:338, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     335 observation, vectorized_env = self.obs_to_tensor(observation)
#     337 with th.no_grad():
# --> 338     actions = self._predict(observation, deterministic=deterministic)
#     339 # Convert to numpy
#     340 actions = actions.cpu().numpy()
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/policies.py:630, in ActorCriticPolicy._predict(self, observation, deterministic)
#     622 def _predict(self, observation: th.Tensor, deterministic: bool = False) -> th.Tensor:
#     623     """
#     624     Get the action according to the policy for a given observation.
#     625
#    (...)
#     628     :return: Taken action according to the policy
#     629     """
# --> 630     return self.get_distribution(observation).get_actions(deterministic=deterministic)
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/policies.py:659, in ActorCriticPolicy.get_distribution(self, obs)
#     657 features = self.extract_features(obs)
#     658 latent_pi = self.mlp_extractor.forward_actor(features)
# --> 659 return self._get_action_dist_from_latent(latent_pi)
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/policies.py:607, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     604 mean_actions = self.action_net(latent_pi)
#     606 if isinstance(self.action_dist, DiagGaussianDistribution):
# --> 607     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     608 elif isinstance(self.action_dist, CategoricalDistribution):
#     609     # Here mean_actions are the logits before the softmax
#     610     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/stable_baselines3/common/distributions.py:153, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     145 """
#     146 Create the distribution given its parameters (mean, std)
#     147
#    (...)
#     150 :return:
#     151 """
#     152 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 153 self.distribution = Normal(mean_actions, action_std)
#     154 return self
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/torch/distributions/normal.py:50, in Normal.__init__(self, loc, scale, validate_args)
#      48 else:
#      49     batch_shape = self.loc.size()
# ---> 50 super(Normal, self).__init__(batch_shape, validate_args=validate_args)
#
# File ~/.conda/envs/sustaingym/lib/python3.9/site-packages/torch/distributions/distribution.py:55, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      53         valid = constraint.check(value)
#      54         if not valid.all():
# ---> 55             raise ValueError(
#      56                 f"Expected parameter {param} "
#      57                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      58                 f"of distribution {repr(self)} "
#      59                 f"to satisfy the constraint {repr(constraint)}, "
#      60                 f"but found invalid values:\n{value}"
#      61             )
#      62 super(Distribution, self).__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (1, 2)) of distribution Normal(loc: torch.Size([1, 2]), scale: torch.Size([1, 2])) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan, nan]], device='cuda:0')

# %%
import numpy as np
from stable_baselines3 import PPO
from tqdm import tqdm
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback, StopTrainingOnNoModelImprovement
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy

# train PPO on May 2019 data

env = BatteryStorageInGridEnv(date='2019-05', seed=195)

# stop_train_callback = StopTrainingOnNoModelImprovement(max_no_improvement_evals=5, min_evals=5, verbose=1)
# eval_callback = EvalCallback(env, eval_freq=1000, callback_after_eval=stop_train_callback, verbose=1)

# model = PPO("MultiInputPolicy", env, verbose=1)
# model.learn(int(1e10), callback=eval_callback)
# model.save("ppo_single_agent_battery_env")

# del model # remove to demonstrate saving and loading

# generate evaluation for PPO trained on May 2019 and tested on May 2019 (in-dist)

model_ppo = PPO.load("ppo_single_agent_battery_env")

episodes = 10

rewards_ppo_19_5 = []
discharge_bids = []
charge_bids = []
state_of_charge = []

for i in tqdm(range(episodes)):
    obs = env.reset(seed=i*10)
    done = False
    rewards = np.zeros(env.MAX_STEPS_PER_EPISODE)
    if i == 0:
        state_of_charge.append(env.battery_charge[-1:][0])
        discharge_bids.append(0.)
        charge_bids.append(0.)
    while not done:
        action, _states = model_ppo.predict(obs)
        if action.shape[0] == 1:
            action = action.reshape((2,))
        if i == 0:
            discharge_bids.append(action[0])
            charge_bids.append(action[1])
            state_of_charge.append(env.battery_charge[-1:][0])
        obs, reward, done, info = env.step(action)
        rewards[env.count - 1] = reward
    rewards_ppo_19_5.append(np.sum(rewards))
# Out:
# 100%|██████████| 10/10 [00:08<00:00,  1.11it/s]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import matplotlib.ticker as plticker

cmap = plt.get_cmap("tab10")

moers = []
forecast_moers = []
demand = []
forecast_demand = []

obs = env.reset(seed=0)

for i in range(env.MAX_STEPS_PER_EPISODE):
    moers.append(env._generate_moer_data(i))
    forecast_moers.append(env._generate_moer_forecast_data(i+1))
    demand.append(env._generate_load_data(i))
    forecast_demand.append(env._generate_load_forecast_data(i+1))

color_cycle = plt.rcParams['axes.prop_cycle']()

fmt = mdates.DateFormatter('%H:%M:%S')

df_load = env._get_demand_data()

time_arr = df_load.columns[:-1]
time_arr = [t + ':00.0' for t in time_arr]
timeArray = [datetime.datetime.strptime(i, '%H:%M:%S.%f') for i in time_arr]

fig, (ax1, ax2)  = plt.subplots(2)

ax3 = ax1.twinx()
ax4 = ax2.twinx()

ax3.plot(timeArray, state_of_charge, label='State of Charge', color=cmap(0))
ax1.plot(timeArray, discharge_bids, label='Discharge Bid Price', color=cmap(1))
ax1.plot(timeArray, charge_bids, label='Charge Bid Price', color=cmap(2))

ax2.plot(timeArray, demand, label='Demand', color=cmap(3))
ax2.plot(timeArray, forecast_demand, label='Demand Forecast', color=cmap(3), linestyle='dashed')
ax4.plot(timeArray, moers, label='MOER', color=cmap(4))
ax4.plot(timeArray, forecast_moers, label='MOER Forecast', color=cmap(4), linestyle='dashed')

ax1.set_ylabel('Energy Level (MWh)')
ax2.set_ylabel('Demand (MWh)')
ax3.set_ylabel('Bid Price ($/MWh)')
ax4.set_ylabel('MOER')

ax2.set_xlabel('Time')

lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]

ax1.xaxis.set_major_formatter(fmt)
ax2.xaxis.set_major_formatter(fmt)
loc = plticker.MultipleLocator(base=0.2) # this locator puts ticks at regular intervals
ax1.xaxis.set_major_locator(loc)
ax2.xaxis.set_major_locator(loc)

fig.legend(lines, labels, bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
plt.show()

# %%
import numpy as np
from stable_baselines3 import A2C
from tqdm import tqdm

# generate evaluation for A2C trained on May 2019 and tested on May 2019 (in-dist)

env = BatteryStorageInGridEnv(date='2019-05', seed=195)

model_a2c = A2C.load("a2c_single_agent_battery_env")

episodes = 10

rewards_a2c_19_5 = []

for i in tqdm(range(episodes)):
    obs = env.reset(seed=i*10)
    done = False
    rewards = np.zeros(env.MAX_STEPS_PER_EPISODE)
    while not done:
        action, _states = model_a2c.predict(obs)
        if action.shape[0] == 1:
            action = action.reshape((2,))
        obs, reward, done, info = env.step(action)
        rewards[env.count - 1] = reward
    rewards_a2c_19_5.append(np.sum(rewards))
# Out:
# 100%|██████████| 10/10 [00:09<00:00,  1.06it/s]

# %%
import numpy as np
from stable_baselines3 import A2C
from tqdm import tqdm

# generate off-line optimal values for May 2019

env = BatteryStorageInGridEnv(date='2019-05', seed=195)

offline_optimal_19_5 = []

for i in tqdm(range(episodes)):
    obs = env.reset(seed=i*10)
    offline_optimal_19_5.append(env._calculate_off_optimal_total_episode_reward())
# Out:
# 100%|██████████| 10/10 [00:07<00:00,  1.40it/s]

# %%
import numpy as np
from stable_baselines3 import PPO
from tqdm import tqdm

# generate evaluation for PPO trained on May 2019 and tested on May 2021 (out-dist)

env = BatteryStorageInGridEnv(date='2021-05', seed=215)

model_ppo_out = PPO.load("ppo_single_agent_battery_env")

episodes = 10

rewards_ppo_21_5 = []

for i in tqdm(range(episodes)):
    obs = env.reset(seed=i*10)
    done = False
    rewards = np.zeros(env.MAX_STEPS_PER_EPISODE)
    while not done:
        action, _states = model_ppo_out.predict(obs)
        if action.shape[0] == 1:
            action = action.reshape((2,))
        obs, reward, done, info = env.step(action)
        rewards[env.count - 1] = reward
    rewards_ppo_21_5.append(np.sum(rewards))
# Out:
# 100%|██████████| 10/10 [00:08<00:00,  1.12it/s]

# %%
import numpy as np
from stable_baselines3 import A2C
from tqdm import tqdm

# generate evaluation for A2C trained on May 2019 and tested on May 2021 (out-dist)

env = BatteryStorageInGridEnv(date='2021-05', seed=215)

model_a2c_out = A2C.load("a2c_single_agent_battery_env")

episodes = 10

rewards_a2c_21_5 = []

for i in tqdm(range(episodes)):
    obs = env.reset(seed=i*10)
    done = False
    rewards = np.zeros(env.MAX_STEPS_PER_EPISODE)
    while not done:
        action, _states = model_a2c_out.predict(obs)
        if action.shape[0] == 1:
            action = action.reshape((2,))
        obs, reward, done, info = env.step(action)
        rewards[env.count - 1] = reward
    rewards_a2c_21_5.append(np.sum(rewards))
# Out:
# 100%|██████████| 10/10 [00:10<00:00,  1.00s/it]

# %%
import numpy as np
from stable_baselines3 import A2C
from tqdm import tqdm

# generate off-line optimal values for May 2019

env = BatteryStorageInGridEnv(date='2021-05', seed=215)

offline_optimal_21_5 = []

for i in tqdm(range(episodes)):
    obs = env.reset(seed=i*10)
    offline_optimal_21_5.append(env._calculate_off_optimal_total_episode_reward())
# Out:
# 100%|██████████| 10/10 [00:07<00:00,  1.38it/s]

# %%
import numpy as np
import matplotlib.pyplot as plt

print("2019/5 PPO: ", rewards_ppo_19_5)
print("2019/5 A2C: ", rewards_a2c_19_5)
print("2019/5 Offline Optimal: ", offline_optimal_19_5)
print("2021/5 PPO: ", rewards_ppo_21_5)
print("2021/5 A2C: ", rewards_a2c_21_5)
print("2021/5 Offline Optimal: ", offline_optimal_21_5)

models = ['Offline', 'PPO', 'A2C']
in_dist = [np.mean(offline_optimal_19_5), np.mean(rewards_ppo_19_5), np.mean(rewards_a2c_19_5)]
out_dist = [np.mean(offline_optimal_21_5), np.mean(rewards_ppo_21_5), np.mean(rewards_a2c_21_5)]

x_axis = np.arange(len(models))

plt.bar(x_axis - 0.2, in_dist, width=0.4, label='In-Dist', color='blue')
plt.bar(x_axis + 0.2, out_dist, width=0.4, label='Out-Dist', color='orange')

in_dist_err = [np.std(offline_optimal_19_5), np.std(rewards_ppo_19_5), np.std(rewards_a2c_19_5)]
out_dist_err = [np.std(offline_optimal_21_5), np.std(rewards_ppo_21_5), np.std(rewards_a2c_21_5)]

plt.errorbar(x_axis - 0.2, in_dist, yerr=in_dist_err, fmt='o', color='gray')
plt.errorbar(x_axis + 0.2, out_dist, yerr=out_dist_err, fmt='o', color='gray')

plt.xticks(x_axis, models)
plt.legend()
plt.show()
# Out:
# 2019/5 PPO:  [2245.0145741723068, 2558.4557707267295, 2536.6470375887716, 2213.9489259221714, 2545.763597560765, 2602.458985199197, 2372.820422435832, 2548.4725186985274, 2261.2602848462757, 2779.4824376099523]
# 2019/5 A2C:  [2245.0145743153016, 2558.4557716921063, 2536.647038219378, 2213.948927097822, 2545.763598501142, 2602.458988265422, 2372.82042346052, 2548.472526844007, 2261.2602856102226, 2779.4824385186284]
# 2019/5 Offline Optimal:  [23051.710297436803, 18248.597237755643, 18994.697055206787, 22868.55334810844, 16514.00674815259, 33131.47019110864, 14612.253560855821, 22389.303426021896, 23079.613407532303, 23031.783863923756]
# 2021/5 PPO:  [2743.0189450456783, 2609.6690354598877, 2641.4290383788198, 2714.706752567427, 2342.052034742505, 2732.207455008233, 2753.6307763219734, 2784.0557684839923, 2722.8755581028713, 2835.9102791492815]
# 2021/5 A2C:  [2743.0189478052616, 2609.6690381383055, 2641.42903982744, 2714.7067542683335, 2342.0520677395284, 2732.207453737356, 2753.6307779419335, 2784.0557688661515, 2722.8755588359236, 2835.9102810094723]
# 2021/5 Offline Optimal:  [20482.670758292246, 19429.36173842518, 16713.67791627479, 22916.353857972834, 18087.993419986706, 20595.192383295172, 17483.9390511944, 21319.578990298218, 22556.99662278885, 21071.943076509524]

# %%
import seaborn as sns
import pandas as pd

rewards_ppo_19_5 = np.array(rewards_ppo_19_5)
rewards_ppo_21_5 = np.array(rewards_ppo_21_5)
offline_optimal_19_5 = np.array(offline_optimal_19_5)
offline_optimal_21_5 = np.array(offline_optimal_21_5)

data1 = np.array([offline_optimal_19_5, offline_optimal_21_5])
data2 = np.array([rewards_ppo_19_5, rewards_ppo_21_5, rewards_ppo_19_5, rewards_ppo_21_5])

fig, (ax1, ax2) = plt.subplots(2)

xticklabels1 = ['Offline 2019', 'Offline 2021']
xticklabels2 = ['PPO in-dist', 'PPO out-dist', 'A2C in-dist', 'A2C out-dist']

df = pd.DataFrame(data = data1.T, columns = xticklabels1)
df2 = pd.DataFrame(data = data2.T, columns = xticklabels2)

ax1.set_xticks([1, 2])
ax1.set_xticklabels(xticklabels1)

ax1.set_ylabel('Reward ($)')

ax1.violinplot(df, showmedians=True)

ax2.set_xticks([1, 2, 3, 4])
ax2.set_xticklabels(xticklabels2)

ax2.set_ylabel('Reward ($)')

ax2.violinplot(df2, showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f02d675b220>,
#   <matplotlib.collections.PolyCollection at 0x7f02d675b5e0>,
#   <matplotlib.collections.PolyCollection at 0x7f02d675b9a0>,
#   <matplotlib.collections.PolyCollection at 0x7f02d675bd60>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f02d675b130>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f02d6756b80>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f02d6756c70>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x7f02d67698e0>}
