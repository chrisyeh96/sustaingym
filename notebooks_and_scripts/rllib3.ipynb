# %%
from ray import tune
from ray.air import session


def objective(x, a, b):
    return a / (x ** 0.5 + 1) + b


def trainable(config: dict):
    intermediate_score = 0
    for x in range(20):
        intermediate_score = objective(x, config["a"], config["b"])
        session.report({"score": intermediate_score, "score2": intermediate_score * 2,
                        "score3": intermediate_score * 3, "final_score": 0
                        })  # This sends the score to Tune.
    
    session.report({"final_score": [2, 3, 4, 5]})

a_param = tune.grid_search([2, 3])
b_param = tune.grid_search([4, 5])

tuner = tune.Tuner(trainable, param_space={"a": a_param, "b": b_param})
results = tuner.fit()
# Out:
# 2023-04-05 22:17:09,296	INFO worker.py:1553 -- Started a local Ray instance.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-04-05 22:17:14</td></tr>
# <tr><td>Running for: </td><td>00:00:03.63        </td></tr>
# <tr><td>Memory:      </td><td>2.1/15.3 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 0/4 CPUs, 0/1 GPUs, 0.0/7.96 GiB heap, 0.0/3.98 GiB objects (0.0/1.0 accelerator_type:T4)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc                </th><th style="text-align: right;">  a</th><th style="text-align: right;">  b</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_9be2c_00000</td><td>TERMINATED</td><td>172.31.19.228:19508</td><td style="text-align: right;">  2</td><td style="text-align: right;">  4</td><td style="text-align: right;">    21</td><td style="text-align: right;">       0.123336 </td></tr>
# <tr><td>trainable_9be2c_00001</td><td>TERMINATED</td><td>172.31.19.228:19554</td><td style="text-align: right;">  3</td><td style="text-align: right;">  4</td><td style="text-align: right;">    21</td><td style="text-align: right;">       0.0611324</td></tr>
# <tr><td>trainable_9be2c_00002</td><td>TERMINATED</td><td>172.31.19.228:19556</td><td style="text-align: right;">  2</td><td style="text-align: right;">  5</td><td style="text-align: right;">    21</td><td style="text-align: right;">       0.0760999</td></tr>
# <tr><td>trainable_9be2c_00003</td><td>TERMINATED</td><td>172.31.19.228:19558</td><td style="text-align: right;">  3</td><td style="text-align: right;">  5</td><td style="text-align: right;">    21</td><td style="text-align: right;">       0.0761952</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name           </th><th>date               </th><th>done  </th><th>episodes_total  </th><th>experiment_id                   </th><th>experiment_tag  </th><th>final_score  </th><th>hostname        </th><th style="text-align: right;">  iterations_since_restore</th><th>node_ip      </th><th style="text-align: right;">  pid</th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  timesteps_since_restore</th><th>timesteps_total  </th><th style="text-align: right;">  training_iteration</th><th>trial_id   </th><th style="text-align: right;">  warmup_time</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_9be2c_00000</td><td>2023-04-05_22-17-12</td><td>True  </td><td>                </td><td>23694a70640146f3ae629f1346aefaa5</td><td>0_a=2,b=4       </td><td>[2, 3, 4, 5] </td><td>ip-172-31-19-228</td><td style="text-align: right;">                        21</td><td>172.31.19.228</td><td style="text-align: right;">19508</td><td style="text-align: right;">            0.123336</td><td style="text-align: right;">         0.0038631</td><td style="text-align: right;">      0.123336</td><td style="text-align: right;"> 1680733032</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                  21</td><td>9be2c_00000</td><td style="text-align: right;">   0.00288033</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# 2023-04-05 22:17:14,755	INFO tune.py:798 -- Total run time: 4.38 seconds (3.61 seconds for the tuning loop).

# %%
{result.log_dir: result.metrics_dataframe for result in results}
{result.log_dir: 0 for result in results}
# Out:
# {PosixPath('/home/ubuntu/ray_results/trainable_2023-04-05_22-17-07/trainable_9be2c_00000_0_a=2,b=4_2023-04-05_22-17-11'): 0,
#  PosixPath('/home/ubuntu/ray_results/trainable_2023-04-05_22-17-07/trainable_9be2c_00001_1_a=3,b=4_2023-04-05_22-17-12'): 0,
#  PosixPath('/home/ubuntu/ray_results/trainable_2023-04-05_22-17-07/trainable_9be2c_00002_2_a=2,b=5_2023-04-05_22-17-12'): 0,
#  PosixPath('/home/ubuntu/ray_results/trainable_2023-04-05_22-17-07/trainable_9be2c_00003_3_a=3,b=5_2023-04-05_22-17-12'): 0}

# %%
import os
print(results.get_dataframe()['logdir'].iloc[0])
os.listdir(results.get_dataframe()['logdir'].iloc[0])
# Out:
# /home/ubuntu/ray_results/trainable_2023-04-05_22-17-07/trainable_9be2c_00000_0_a=2,b=4_2023-04-05_22-17-11
# ['params.pkl',
#  'result.json',
#  'events.out.tfevents.1680733031.ip-172-31-19-228',
#  'progress.csv',
#  'params.json']

# %%
import pandas as pd

pd.read_csv(os.path.join(results.get_dataframe()['logdir'].iloc[0], 'progress.csv'))
# Out:
#        score     score2     score3   final_score  time_this_iter_s   done  \
# 0   6.000000  12.000000  18.000000             0          0.000129  False
# 1   5.000000  10.000000  15.000000             0          0.026007  False
# 2   4.828427   9.656854  14.485281             0          0.005542  False
# 3   4.732051   9.464102  14.196152             0          0.007002  False
# 4   4.666667   9.333333  14.000000             0          0.008595  False
# 5   4.618034   9.236068  13.854102             0          0.004122  False
# 6   4.579796   9.159592  13.739388             0          0.003939  False
# 7   4.548584   9.097168  13.645751             0          0.003945  False
# 8   4.522408   9.044815  13.567223             0          0.003852  False
# 9   4.500000   9.000000  13.500000             0          0.003694  False
# 10  4.480506   8.961012  13.441518             0          0.003601  False
# 11  4.463325   8.926650  13.389975             0          0.003908  False
# 12  4.448018   8.896037  13.344055             0          0.009763  False
# 13  4.434259   8.868517  13.302776             0          0.007034  False
# 14  4.421793   8.843587  13.265380             0          0.003833  False
# 15  4.410426   8.820852  13.231279             0          0.005769  False
# 16  4.400000   8.800000  13.200000             0          0.006687  False
# 17  4.390388   8.780776  13.171165             0          0.003969  False
# 18  4.381487   8.762974  13.144461             0          0.004221  False
# 19  4.373211   8.746422  13.119633             0          0.003862  False
# 20       NaN        NaN        NaN  [2, 3, 4, 5]          0.003863  False
#
#     timesteps_total  episodes_total  training_iteration     trial_id  ...  \
# 0               NaN             NaN                   1  9be2c_00000  ...
# 1               NaN             NaN                   2  9be2c_00000  ...
# 2               NaN             NaN                   3  9be2c_00000  ...
# 3               NaN             NaN                   4  9be2c_00000  ...
# 4               NaN             NaN                   5  9be2c_00000  ...
# 5               NaN             NaN                   6  9be2c_00000  ...
# 6               NaN             NaN                   7  9be2c_00000  ...
# 7               NaN             NaN                   8  9be2c_00000  ...
# 8               NaN             NaN                   9  9be2c_00000  ...
# 9               NaN             NaN                  10  9be2c_00000  ...
# 10              NaN             NaN                  11  9be2c_00000  ...
# 11              NaN             NaN                  12  9be2c_00000  ...
# 12              NaN             NaN                  13  9be2c_00000  ...
# 13              NaN             NaN                  14  9be2c_00000  ...
# 14              NaN             NaN                  15  9be2c_00000  ...
# 15              NaN             NaN                  16  9be2c_00000  ...
# 16              NaN             NaN                  17  9be2c_00000  ...
# 17              NaN             NaN                  18  9be2c_00000  ...
# 18              NaN             NaN                  19  9be2c_00000  ...
# 19              NaN             NaN                  20  9be2c_00000  ...
# 20              NaN             NaN                  21  9be2c_00000  ...
#
#                    date   timestamp  time_total_s    pid          hostname  \
# 0   2023-04-05_22-17-12  1680733032      0.000129  19508  ip-172-31-19-228
# 1   2023-04-05_22-17-12  1680733032      0.026136  19508  ip-172-31-19-228
# 2   2023-04-05_22-17-12  1680733032      0.031678  19508  ip-172-31-19-228
