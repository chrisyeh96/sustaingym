# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %cd ..
# Out:
# /home/ubuntu/sustaingym

# %%
from datetime import datetime, timedelta
import os
import pytz

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")

from sustaingym.data.load_moer import load_monthly_moer

# %%
moer_data_dir = 'sustaingym/data/moer/'
cnt = 0

minr, minf = 100., 100.
maxr, maxf = -100., 100.

for file in os.listdir(moer_data_dir):
    print(file)
    cnt += 1

    file_path = os.path.join(moer_data_dir, file)
    df = pd.read_csv(file_path,
                    compression='gzip',
                    index_col='time')
    df.index = pd.to_datetime(pd.DatetimeIndex(df.index))

    # check if any null values exist
    if len(df[df.isnull().any(axis=1)]) > 0:
        print("Null value")
        display(df[df.isnull().any(axis=1)])
    
    # check sorting order
    if df.index[0] < df.index[1]:
        print("Not sorted descending")
        display(df.head())

    minr = min(minr, np.min(df.min()))
    maxr = max(minr, np.max(df.max()['moer']))

print('mins: ', minr)
print('maxs: ', maxr)
print("total count: ", cnt)
# show example
display(df)
# Out:
# SGIP_CAISO_PGE_2021-07.csv.gz
# SGIP_CAISO_PGE_2019-09.csv.gz
# SGIP_CAISO_PGE_2019-07.csv.gz
# SGIP_CAISO_SCE_2021-05.csv.gz
# SGIP_CAISO_SCE_2019-05.csv.gz
# SGIP_CAISO_SCE_2019-11.csv.gz
# SGIP_CAISO_SCE_2019-06.csv.gz
# SGIP_CAISO_PGE_2020-04.csv.gz
# SGIP_CAISO_PGE_2021-08.csv.gz
# SGIP_CAISO_PGE_2019-12.csv.gz
# SGIP_CAISO_PGE_2019-11.csv.gz
# SGIP_CAISO_SCE_2020-05.csv.gz
# SGIP_CAISO_SCE_2021-07.csv.gz
# SGIP_CAISO_SCE_2021-06.csv.gz
# SGIP_CAISO_SCE_2020-03.csv.gz
# SGIP_CAISO_SCE_2021-08.csv.gz
# SGIP_CAISO_SCE_2019-08.csv.gz
# SGIP_CAISO_PGE_2020-05.csv.gz
# SGIP_CAISO_PGE_2019-10.csv.gz
# SGIP_CAISO_SCE_2019-07.csv.gz
# SGIP_CAISO_PGE_2021-05.csv.gz
# SGIP_CAISO_SCE_2019-12.csv.gz
# SGIP_CAISO_SCE_2019-10.csv.gz
# SGIP_CAISO_PGE_2019-06.csv.gz
# SGIP_CAISO_SCE_2020-02.csv.gz
# SGIP_CAISO_SCE_2019-09.csv.gz
# SGIP_CAISO_PGE_2020-02.csv.gz
# SGIP_CAISO_SCE_2020-04.csv.gz
# SGIP_CAISO_PGE_2020-03.csv.gz
# SGIP_CAISO_PGE_2019-05.csv.gz
# SGIP_CAISO_PGE_2019-08.csv.gz
# SGIP_CAISO_PGE_2021-06.csv.gz
# mins:  0.0
# maxs:  0.66375
# total count:  32
#                                moer        f1        f2        f3        f4  \
# time
# 2021-07-02 00:00:00+00:00  0.295764  0.306905  0.314137  0.318465  0.326010
#
#                                 f31       f32       f33       f34       f35  \
# time
# 2021-07-02 00:00:00+00:00  0.394876  0.394062  0.417608  0.415625  0.416337
# 2021-07-01 23:55:00+00:00  0.393285  0.394876  0.394062  0.417608  0.415625
# 2021-07-01 23:50:00+00:00  0.423547  0.393285  0.394876  0.394062  0.417608
# 2021-07-01 23:45:00+00:00  0.420832  0.423547  0.393285  0.394876  0.394062
# 2021-07-01 23:40:00+00:00  0.413594  0.420832  0.423547  0.393285  0.394876
# ...                             ...       ...       ...       ...       ...
# 2021-05-31 00:20:00+00:00  0.367087  0.364526  0.334751  0.330890  0.345263
# 2021-05-31 00:15:00+00:00  0.366929  0.367087  0.364526  0.334751  0.330890
# 2021-05-31 00:10:00+00:00  0.370463  0.366929  0.367087  0.364526  0.334751
# 2021-05-31 00:05:00+00:00  0.357427  0.370463  0.366929  0.367087  0.364526
# 2021-05-31 00:00:00+00:00  0.361444  0.356846  0.369976  0.366536  0.366761
#
#                                 f36
# time
# 2021-07-02 00:00:00+00:00  0.415721
# 2021-07-01 23:55:00+00:00  0.416337
# 2021-07-01 23:50:00+00:00  0.415625
# 2021-07-01 23:45:00+00:00  0.417608
# 2021-07-01 23:40:00+00:00  0.394062
# ...                             ...
# 2021-05-31 00:20:00+00:00  0.334226
# 2021-05-31 00:15:00+00:00  0.345263
# 2021-05-31 00:10:00+00:00  0.330890
# 2021-05-31 00:05:00+00:00  0.334751
# 2021-05-31 00:00:00+00:00  0.364321
#
# [9217 rows x 37 columns]

# %%
AM_LA = pytz.timezone('America/Los_Angeles')

def plot_moer(day: datetime, ba: str, save_dir: str, forecast_freq=36):
    df = load_monthly_moer(day.year, day.month, ba, save_dir)
    df = df[(day <= df.index) & (df.index <= day + timedelta(days=1, seconds=600))]
    df.sort_index(inplace=True)

    # every so often, plot emissions forecast
    for i in range(0, len(df['moer']), forecast_freq):
        forecasts = df.iloc[i].drop('moer').values
        indices = df.iloc[i+1:i+1+len(forecasts)].index
        if i + len(forecasts) + 1> len(df['moer']):
            continue
        
        if i == 0:
            plt.plot(indices, forecasts, color='red', alpha=0.3, label='forecasts')
        else:
            plt.plot(indices, forecasts, color='red', alpha=0.3)

    dt_str = day.strftime('%Y-%m-%d')
    plt.title(f'MOER vs. Forecasted MOER: {dt_str}')
    plt.plot(df['moer'], linewidth=2, label='actual')
    plt.xlabel('time (UTC)')
    plt.ylabel('MOER (kg CO2 / kWh)')
    plt.xticks(rotation=30)
    plt.legend()

plot_moer(datetime(2021, 6, 3, tzinfo=AM_LA), 'SGIP_CAISO_SCE', moer_data_dir)

# %%
plot_moer(datetime(2019, 6, 15, tzinfo=AM_LA), 'SGIP_CAISO_SCE', moer_data_dir)
